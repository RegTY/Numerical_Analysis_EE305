# %%
# %matplotlib notebook
import matplotlib
from matplotlib.widgets import Slider
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set(color_codes=True)
sns.set_style("darkgrid")

# %%
 x = np.linspace(0,50,100)
# def equationf(x):
#     y = np.log(x)
#     return y



t = [0, 10, 15,20,22.5,30]

s = [0, 227.04,362.78, 517.35, 602.97,901.67]

# %%
fig, ax = plt.subplots()



ax = plt.scatter(t,s ,label = "Original Data")



# halt = (b-a)/2
ab = 16

n = 1


fx1 = s[1]
fx2 = s[3]
fx3 = s[4]

x1 = t[1]
x2 = t[3]
x3 = t[4]


y = fx1*(ab - x2)/(x1 - x2)*(ab - x3)/(x1 - x3) +fx2*(ab - x1)/(x2 - x1)*(ab - x3)/(x2-x3) + fx3*(ab - x1)/(x3 - x1)*(ab - x2)/(x3-x2)
def function(ab):
    y = fx1*(ab - x2)/(x1 - x2)*(ab - x3)/(x1 - x3) +fx2*(ab - x1)/(x2 - x1)*(ab - x3)/(x2-x3) + fx3*(ab - x1)/(x3 - x1)*(ab - x2)/(x3-x2)
    return y



# ax[0].title.set_title("test")
ax = plt.scatter(ab,y, color = 'Red', label = "Interpolated value")
ax= plt.plot(x,function(x), color = 'orange', label = "Interpolated value")




print(y)
# ax = plt.plot(x,interpol(x))
plt.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 391.20936
